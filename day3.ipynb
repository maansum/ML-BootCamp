# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
X, _ =make_blobs(n_samples = 300,centers =5, cluster_std= 0.90,random_state=0)

# %%
plt.scatter(X[:,0],X[:,1],s=50)
plt.xlabel('feature 1')
plt.ylabel('feature 2')
plt.title('synthetic data')
plt.show()

# %%
k=10 
kmeans= KMeans(n_clusters=k)
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=10)

# %%
labels = kmeans.labels_
centroids= kmeans.cluster_centers_

# %%
labels, centroids
# Out:
# (array([0, 2, 7, 5, 4, 4, 3, 1, 8, 6, 5, 5, 1, 6, 2, 7, 7, 3, 5, 9, 3, 4,
#         7, 0, 4, 1, 9, 8, 2, 9, 3, 5, 1, 0, 5, 6, 8, 2, 4, 3, 7, 9, 7, 1,
#         5, 4, 8, 4, 0, 9, 9, 3, 9, 9, 5, 9, 8, 6, 2, 0, 9, 3, 4, 6, 6, 5,
#         5, 6, 9, 0, 4, 8, 0, 0, 0, 0, 0, 2, 7, 8, 6, 2, 7, 5, 5, 2, 3, 8,
#         3, 9, 6, 3, 3, 0, 4, 2, 7, 2, 6, 7, 0, 4, 8, 2, 3, 1, 9, 3, 1, 9,
#         7, 6, 4, 3, 5, 8, 7, 5, 9, 3, 7, 6, 5, 6, 5, 4, 9, 8, 3, 6, 8, 2,
#         0, 2, 2, 3, 5, 5, 9, 0, 1, 0, 5, 9, 1, 4, 1, 9, 2, 7, 5, 2, 0, 7,
#         0, 7, 4, 2, 5, 2, 4, 1, 6, 7, 7, 4, 1, 5, 2, 7, 3, 3, 7, 0, 3, 7,
#         6, 6, 9, 3, 7, 4, 3, 7, 9, 6, 8, 1, 1, 1, 9, 5, 7, 6, 7, 7, 2, 9,
#         6, 3, 9, 5, 7, 6, 8, 2, 7, 0, 9, 2, 8, 5, 3, 4, 7, 7, 6, 9, 9, 4,
#         8, 1, 5, 3, 8, 9, 9, 2, 7, 6, 6, 1, 1, 0, 1, 4, 4, 7, 5, 3, 2, 5,
#         6, 8, 1, 3, 5, 5, 6, 5, 6, 2, 2, 3, 4, 3, 3, 4, 2, 8, 3, 5, 7, 7,
#         2, 3, 2, 6, 1, 5, 1, 9, 3, 6, 4, 7, 3, 3, 3, 7, 0, 0, 3, 8, 1, 9,
#         8, 9, 6, 6, 5, 8, 4, 9, 0, 5, 5, 4, 8, 7], dtype=int32),
#  array([[ 9.38036037, -2.21606232],
#         [ 1.19147521,  4.29782951],
#         [-1.10043895,  7.93345979],
#         [ 1.90944052,  0.87756281],
#         [-1.4142677 ,  2.8590178 ],
#         [ 9.11803834, -2.46182573],
#         [-1.38294474,  7.69069407],
#         [ 0.85448708,  4.36974224],
#         [ 2.24529221,  0.88309205],
#         [-1.70504043,  2.9652215 ]]))

# %%
plt.scatter(X[:,0],X[:,1],
            c=labels,
            cmap='viridis',
            s=50)

plt.scatter(centroids[:,0],centroids[:,1],
            c='red',
            marker='*', s=200)
plt.show()

# %%
inertias=[]

for i in range(1,11):
  kmeans = KMeans(n_clusters=i)
  kmeans.fit(X)
  inertias.append(kmeans.inertia_)
plt.plot(range(1,11),inertias)
plt.xlabel('no.cluster')
plt.ylabel('inertia')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0, 0.5, 'inertia')
